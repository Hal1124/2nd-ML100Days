# %% [markdown]
# # 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 資料來源：Google Play Store Apps
#
# Q1：你選的這組資料為何重要
# 透過 google play 數據了解市場狀況
# Q2：資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 從google story 而來
# Q3：蒐集而來的資料型態為何
# 主要為文字、數值。
# Q4：這組資料想解決的問題如何評估
# 使用者，使用 app 喜好分析
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# Q1：核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 如何減少空車時間
# Q2：資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 優惠方案效益(下雨天/連假/特定地區活動/生日)：APP叫車紀錄
# 客戶搭乘滿意度：APP滿意度回饋
# 廣告效益：FB、IG、Google Ads... ### Q3：蒐集而來的資料型態為何
# 文字、數值
# ### Q4：你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 廣告是否有提升知名度
# 客戶搭乘滿意度是否有保持回頭客
# 優惠方案是否有增加叫車量
# 作業3：
# 練習時間
# 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    return sum(pow(y - yp, 2)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 238.623
